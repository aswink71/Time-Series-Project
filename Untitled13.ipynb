# %% [markdown]
# <a href="https://colab.research.google.com/github/aswink71/Time-Series-Project/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
# importing method for calculating the data
import numpy as nmy
#applying the library for manupulated the data-set
import pandas as pdns
# Data Visualization
import matplotlib.pyplot as mtpl
# here we use the sea born libraries to draw the graph
import seaborn as sns

# use this library for this project
from statsmodels.tsa.stattools import adfuller, acf, pacf
# apply the method of that
import statsmodels.api as sm

# For cross-validation, specifically with time series data,
from sklearn.model_selection import train_test_split,TimeSeriesSplit

# Metrics to evaluate how well models perform
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# using the lyers in the algorithms
from keras.models import Sequential
from keras.layers import Dense,Dropout

# Progress Tracking
from tqdm import tqdm

# removing the causility
import warnings
warnings.filterwarnings("ignore")

# adding this method for timing
from datetime import datetime

# %%
# creating a method for reading the dataset
def read_data(file_path):
    # passed the information with the data
    data=pdns.read_csv(file_path)
    # returning the data
    return data

# %%
STC_DTA=read_data('/content/drive/MyDrive/Time series project/STC 7010 Historical Data (2).csv')
MOB_DTA=read_data('/content/drive/MyDrive/Time series project/MOBILY 7020 Historical Data (2).csv')
ZAIN_DTA=read_data('/content/drive/MyDrive/Time series project/ZAIN KSA 7030 Historical Data (2).csv')

# %%
STC_DTA.head()
# Out:
#          Date  Price   Open   High    Low   Vol. Change %
# 0  11/21/2022  37.95  37.80  37.95  37.60  1.90M    0.40%
# 1  11/20/2022  37.80  37.85  37.85  37.60  1.82M    0.40%
# 2  11/17/2022  37.65  38.00  38.05  37.65  3.20M   -0.92%
# 3  11/16/2022  38.00  37.80  38.00  37.15  3.44M    0.53%
# 4  11/15/2022  37.80  38.30  38.30  37.50  4.75M   -1.31%

# %%
MOB_DTA.head()
# Out:
#          Date  Price   Open   High    Low     Vol. Change %
# 0  11/21/2022  35.65  35.20  35.65  34.85  540.30K   -0.56%
# 1  11/20/2022  35.85  36.50  36.50  35.20  385.81K   -1.65%
# 2  11/17/2022  36.45  35.85  36.50  35.55  459.02K    0.97%
# 3  11/16/2022  36.10  35.00  36.50  35.00  474.77K    3.14%
# 4  11/15/2022  35.00  35.80  36.00  34.95  633.20K   -2.78%

# %%
ZAIN_DTA.head()
# Out:
#          Date  Price   Open   High    Low   Vol. Change %
# 0  11/21/2022  11.40  11.42  11.50  11.30  1.75M   -0.87%
# 1  11/20/2022  11.50  11.50  11.52  11.38  1.24M   -0.17%
# 2  11/17/2022  11.52  11.48  11.54  11.36  1.39M    0.35%
# 3  11/16/2022  11.48  11.34  11.52  11.24  1.98M    0.88%
# 4  11/15/2022  11.38  11.26  11.38  11.18  2.29M    1.25%

# %%
STC_DTA.shape
# Out:
# (1471, 7)

# %%
STC_DTA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1471 non-null   object
#  1   Price     1471 non-null   float64
#  2   Open      1471 non-null   float64
#  3   High      1471 non-null   float64
#  4   Low       1471 non-null   float64
#  5   Vol.      1471 non-null   object
#  6   Change %  1471 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 80.6+ KB

# %%
MOB_DTA.shape
# Out:
# (1471, 7)

# %%
MOB_DTA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1471 non-null   object
#  1   Price     1471 non-null   float64
#  2   Open      1471 non-null   float64
#  3   High      1471 non-null   float64
#  4   Low       1471 non-null   float64
#  5   Vol.      1471 non-null   object
#  6   Change %  1471 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 80.6+ KB

# %%
ZAIN_DTA.shape
# Out:
# (1469, 7)

# %%
ZAIN_DTA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1469 entries, 0 to 1468
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1469 non-null   object
#  1   Price     1469 non-null   float64
#  2   Open      1469 non-null   float64
#  3   High      1469 non-null   float64
#  4   Low       1469 non-null   float64
#  5   Vol.      1469 non-null   object
#  6   Change %  1469 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 80.5+ KB

# %%
print(STC_DTA.isnull().sum())
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
print(MOB_DTA.isnull().sum())
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
print(ZAIN_DTA.isnull().sum())
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
print("STC_DTA Duplicate Rows:", STC_DTA.duplicated().sum())
# Out:
# STC_DTA Duplicate Rows: 0

# %%
print("ZAIN_DTA Duplicate Rows:", ZAIN_DTA.duplicated().sum())
# Out:
# ZAIN_DTA Duplicate Rows: 0

# %%
print("MOB_DTA Duplicate Rows:", MOB_DTA.duplicated().sum())
# Out:
# MOB_DTA Duplicate Rows: 0

# %%
# Price Distribution (Histogram)
mtpl.figure(figsize=(10, 6))
mtpl.hist(STC_DTA['Price'], bins=30)
mtpl.xlabel('Price')
mtpl.ylabel('Frequency')
mtpl.title('STC Stock Price Distribution')
mtpl.grid(True)
mtpl.show()

# %%
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from PyWavelets) (1.26.4)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 24.5 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
import pywt

# Function to apply Wavelet Denoising to a numerical column
def wavelet_denoise(data,wavelet='db4',level=2):
    coeffs = pywt.wavedec(data,wavelet,level=level) #decomposes the data into wavelet coef
    threshold=nmy.std(coeffs[-1])  # Threshold based on noise level
    coeffs[1:] = [pywt.threshold(c, threshold, mode='soft') for c in coeffs[1:]]  # Apply soft thresholding
    denoised_data = pywt.waverec(coeffs, wavelet) #reconstruction
    # Trim the denoised data to match the original length if necessary
    denoised_data = denoised_data[:len(data)]
    return denoised_data

# Apply denoising to the "Price" column of each dataset
def apply_denoising_to_price_column(dataset):
    denoised_dataset = dataset.copy()
    denoised_dataset['Price'] = wavelet_denoise(dataset['Price'].values)
    return denoised_dataset

# Apply Wavelet Denoising to the "Price" column in each dataset
STC_DTA_denoised = apply_denoising_to_price_column(STC_DTA)
MOB_DTA_denoised = apply_denoising_to_price_column(MOB_DTA)
ZAIN_DTA_denoised = apply_denoising_to_price_column(ZAIN_DTA)

# Visualize original vs denoised data for the "Price" column in STC_DTA
mtpl.figure(figsize=(12, 6))
mtpl.plot(STC_DTA['Price'], label='Original Price (STC_DTA)', color='blue')
mtpl.plot(STC_DTA_denoised['Price'], label='Denoised Price (STC_DTA)', color='orange')
mtpl.title('Wavelet Denoising on STC_DTA - Price')
mtpl.xlabel('Index')
mtpl.ylabel('Price')
mtpl.legend()
mtpl.show()

# %%
# Visualize original vs denoised data for the "Price" column in MOB_DTA
mtpl.figure(figsize=(12, 6))
mtpl.plot(MOB_DTA['Price'], label='Original Price (MOB_DTA)', color='blue')
mtpl.plot(MOB_DTA_denoised['Price'], label='Denoised Price (MOB_DTA)', color='orange')
mtpl.title('Wavelet Denoising on MOB_DTA - Price')
mtpl.xlabel('Index')
mtpl.ylabel('Price')
mtpl.legend()
mtpl.show()

# %%
# Visualize original vs denoised data for the "Price" column in ZAIN_DTA
mtpl.figure(figsize=(12, 6))
mtpl.plot(ZAIN_DTA['Price'], label='Original Price (ZAIN_DTA)', color='blue')
mtpl.plot(ZAIN_DTA_denoised['Price'], label='Denoised Price (ZAIN_DTA)', color='orange')
mtpl.title('Wavelet Denoising on ZAIN_DTA - Price')
mtpl.xlabel('Index')
mtpl.ylabel('Price')
mtpl.legend()
mtpl.show()

# %%
# Import the necessary library and class
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()

# Apply scaling to the "Price" column in each dataset
STC_DTA_denoised['Price'] = scaler.fit_transform(STC_DTA_denoised[['Price']])
MOB_DTA_denoised['Price'] = scaler.fit_transform(MOB_DTA_denoised[['Price']])
ZAIN_DTA_denoised['Price'] = scaler.fit_transform(ZAIN_DTA_denoised[['Price']])

# %%
# Define a function to plot ACF with customizable colors
def plot_acf_custom(data, title, xlabel_color, ylabel_color, title_color, acf_color, lags=30):
    mtpl.figure(figsize=(12, 6))
    sm.graphics.tsa.plot_acf(data, lags=lags, color=acf_color)  # ACF line with custom color
    mtpl.title(title, fontsize=16, color=title_color)  # Title with custom color
    mtpl.xlabel('Lag', fontsize=14, color=xlabel_color)  # X-axis label with custom color
    mtpl.ylabel('Autocorrelation', fontsize=14, color=ylabel_color)  # Y-axis label with custom color
    mtpl.grid(color='gray', linestyle='--', linewidth=0.5)  # Grid lines for clarity
    mtpl.tight_layout()
    mtpl.show()

# Plot ACF for STC_DTA with custom colors
plot_acf_custom(
    data=STC_DTA_denoised['Price'],
    title='Autocorrelation Function (ACF) for STC_DTA Price',
    xlabel_color='green', ylabel_color='red', title_color='blue', acf_color='purple'
)

# Plot ACF for MOB_DTA with custom colors
plot_acf_custom(
    data=MOB_DTA_denoised['Price'],
    title='Autocorrelation Function (ACF) for MOB_DTA Price',
    xlabel_color='blue', ylabel_color='green', title_color='red', acf_color='darkorange'
)

# Plot ACF for ZAIN_DTA with custom colors
plot_acf_custom(
    data=ZAIN_DTA_denoised['Price'],
    title='Autocorrelation Function (ACF) for ZAIN_DTA Price',
    xlabel_color='red', ylabel_color='blue', title_color='green', acf_color='teal'
)

# %%
# Define a function to plot PACF with customizable colors and styles
def plot_pacf_custom(data, title, xlabel_color, ylabel_color, title_color, pacf_color, lags=30, marker='o'):
    mtpl.figure(figsize=(12, 6))
    sm.graphics.tsa.plot_pacf(data, lags=lags, color=pacf_color, markersize=5, marker=marker)  # PACF with marker and color
    mtpl.title(title, fontsize=16, color=title_color)  # Title with custom color
    mtpl.xlabel('Lag', fontsize=14, color=xlabel_color)  # X-axis label with custom color
    mtpl.ylabel('Partial Autocorrelation', fontsize=14, color=ylabel_color)  # Y-axis label with custom color
    mtpl.grid(color='gray', linestyle='--', linewidth=0.5)  # Grid lines for clarity
    mtpl.tight_layout()
    mtpl.show()

# Plot PACF for STC_DTA with custom colors and marker type
plot_pacf_custom(
    data=STC_DTA_denoised['Price'],
    title='Partial Autocorrelation Function (PACF) for STC_DTA Price',
    xlabel_color='green', ylabel_color='red', title_color='blue', pacf_color='purple', lags=30, marker='o'
)

# Plot PACF for MOB_DTA with custom colors and marker type
plot_pacf_custom(
    data=MOB_DTA_denoised['Price'],
    title='Partial Autocorrelation Function (PACF) for MOB_DTA Price',
    xlabel_color='blue', ylabel_color='green', title_color='red', pacf_color='darkorange', lags=30, marker='x'
)

# Plot PACF for ZAIN_DTA with custom colors and marker type
plot_pacf_custom(
    data=ZAIN_DTA_denoised['Price'],
    title='Partial Autocorrelation Function (PACF) for ZAIN_DTA Price',
    xlabel_color='red', ylabel_color='blue', title_color='green', pacf_color='teal', lags=30, marker='s'
)

# %%
STC_DTA_denoised['Date'] = pdns.to_datetime(STC_DTA_denoised['Date'])
MOB_DTA_denoised['Date'] = pdns.to_datetime(MOB_DTA_denoised['Date'])
ZAIN_DTA_denoised['Date'] = pdns.to_datetime(ZAIN_DTA_denoised['Date'])

# %%
STC_DTA_denoised = STC_DTA_denoised.set_index('Date')
MOB_DTA_denoised = MOB_DTA_denoised.set_index('Date')
ZAIN_DTA_denoised = ZAIN_DTA_denoised.set_index('Date')

# %%
STC_DTA_denoised.head()
# Out:
#                Price   Open   High    Low   Vol. Change %
# Date
# 2022-11-21 -0.102884  37.80  37.95  37.60  1.90M    0.40%
# 2022-11-20 -0.105638  37.85  37.85  37.60  1.82M    0.40%
# 2022-11-17 -0.102403  38.00  38.05  37.65  3.20M   -0.92%
# 2022-11-16 -0.092953  37.80  38.00  37.15  3.44M    0.53%
# 2022-11-15 -0.079073  38.30  38.30  37.50  4.75M   -1.31%

# %%
# defining the function with the data
def calculate_metrics(y_true,y_pred):
  # calculating the values of errors with the data
  mse=mean_squared_error(y_true,y_pred)
  #find out the (RMSE) by taking the square root of MSE
  rmse=nmy.sqrt(mse)
  # Determine the actual and anticipated values
  mae=mean_absolute_error(y_true,y_pred)
  # To determine the Percentage Error
  r2=r2_score(y_true,y_pred)
  # To calculate the averagerror
  def mean_absolute_percentage_error(y_true,y_pred):
      # Convert and to numpy arrays if they are not already
      y_true,y_pred=nmy.array(y_true),nmy.array(y_pred)
      # returning the values of data
      return nmy.mean(nmy.abs((y_true - y_pred) / y_true)) *10
  # evaluting the valeus with the data
  mape=mean_absolute_percentage_error(y_true,y_pred)
  # showing the values of this result
  print("Mean Absolute Error (MAE):",mae)
  # evaluting the score with the values
  print("Mean Squared Error (MSE):",mse)
  # finding the values of result with the models
  print("Root Mean Squared Error (RMSE):",rmse)
  # getting the score with the tested data
  print("Mean Absolute Percentage Error (MAPE):",mape)

  print("R-squared (R2):", r2)

# %% [markdown]
# # STC Dataset

# %%
time_steps = 20

# Modifying the data to fit the algorithms
def reshape_data(data,time_steps=20):
    # creating the empty list
    X, y = [], []
    #Fixed the indexing issue
    for i in range(len(data) - time_steps -1):
        # Select the first column (Price_scaled)
        X.append(data[i:(i + time_steps), 0])
        # Select the first column (Price_scaled)
        y.append(data[i + time_steps, 0])
    # returning the data
    return nmy.array(X),nmy.array(y)

# Converting the to a 2D array (adding a second dimension)
price_scaled_Denoise=STC_DTA_denoised['Price'].values.reshape(-1, 1)

# Call reshape_data
X, y=reshape_data(price_scaled_Denoise, time_steps)

# %%
# This ensures that the last 14 data points will be used as the test set
train_size = len(X) - 14
# Separating the feature data X into sets for testing and training.
X_train, X_test = X[:train_size], X[train_size:]
# The training and test sets are separated out of the feature data X.
y_train, y_test = y[:train_size], y[train_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1436, 20)
# y_train shape: (1436,)
# X_test shape: (14, 20)
# y_test shape: (14,)

# %% [markdown]
# # Random Forest Regression

# %%
# use the algorithms with the suitabel parameter
from sklearn.ensemble import RandomForestRegressor
# getting the score of the models
from sklearn.metrics import r2_score
# Setting up optimized hyper-parameters for the algorithms.
rf_model=RandomForestRegressor(n_estimators=100,max_depth=10,min_samples_split=5,random_state=42)

# using the trained infromation to the model
rf_model.fit(X_train,y_train)

# Make forecasts using the test set.
pd_rf_stc=rf_model.predict(X_test)
# calculating the prediction with the algorithms
trn_rf_stc=rf_model.predict(X_train)

# %% [markdown]
# # Training Result

# %%
# Examine the model using the training data.
calculate_metrics(y_train,trn_rf_stc)
# Out:
# Mean Absolute Error (MAE): 0.0158055470084265
# Mean Squared Error (MSE): 0.0005795750459507233
# Root Mean Squared Error (RMSE): 0.024074364912718325
# Mean Absolute Percentage Error (MAPE): 1.6836912448971528
# R-squared (R2): 0.9994211650783991

# %% [markdown]
# # Testing Result

# %%
# Examine the model using the test data.
calculate_metrics(y_test, pd_rf_stc)
# Out:
# Mean Absolute Error (MAE): 0.035404647677451294
# Mean Squared Error (MSE): 0.001632246826793459
# Root Mean Squared Error (RMSE): 0.04040107457473698
# Mean Absolute Percentage Error (MAPE): 0.24761338676764938
# R-squared (R2): 0.9259542319615895

# %% [markdown]
# # Reshape Dataset

# %%
# Modify the information for ANN
X_train_ann=X_train.reshape(X_train.shape[0],X_train.shape[1], 1)
# getting the vlaues of changing the shape
X_test_ann=X_test.reshape(X_test.shape[0],X_test.shape[1], 1)

# %% [markdown]
# # ANN Model

# %%
# adding the layers of this algorithms
from tensorflow.keras.models import Sequential
#Utilize the algorithms with the lyes.
from tensorflow.keras.layers import Dense

modl_ann=Sequential()
# adding the layers in the algorithms
modl_ann.add(Dense(units=50,activation='relu',input_dim=X_train_ann.shape[1]))
# Including an additional dropout layer to avoid overfitting
modl_ann.add(Dense(units=25,activation='relu'))
# Regression's output layer
modl_ann.add(Dense(units=1))

# Putting the model together.
modl_ann.compile(optimizer='adam',loss='mse')

#Getting the model informed.
modl_ann.fit(X_train_ann,y_train,epochs=100,batch_size=32,verbose=1,validation_data=(X_test_ann,y_test))
# Out:
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.7705 - val_loss: 0.0559
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0322 - val_loss: 0.0294
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250 - val_loss: 0.0165
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0169 - val_loss: 0.0107
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0110 - val_loss: 0.0076
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0041
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0030
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0042 - val_loss: 9.3868e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 7.4781e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - val_loss: 8.3592e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - val_loss: 6.8249e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 8.1104e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 4.7997e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 7.3021e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - val_loss: 6.5099e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 5.3408e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 7.4664e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 6.9357e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 6.6243e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 4.8687e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 6.6001e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 5.6792e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 9.0587e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 3.8619e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 5.5996e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 3.4572e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 8.1915e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 7.2885e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 7.1915e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 7.7890e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 8.9791e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 8.1124e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 9.1321e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 8.0883e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 5.9043e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 6.6973e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 6.4969e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 7.0571e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 7.6300e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 6.9914e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 5.2054e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 5.0821e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 6.1843e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 6.8345e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 9.9388e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 6.3906e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 6.6047e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 6.9679e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 8.9565e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 8.6853e-04

# %%
modl_ann.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 50)                  │           1,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,055 (27.56 KB)
#  Trainable params: 2,351 (9.18 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,704 (18.38 KB)

# %%
# Predicted using the testing and training sets.
train_pred_ann=modl_ann.predict(X_train_ann)
# Forecasting the training as well as testing sets.
test_pred_ann=modl_ann.predict(X_test_ann)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# # Training Result

# %%
print("ANN Training Set Evaluation:")
calculate_metrics(y_train,train_pred_ann.flatten())
# Out:
# ANN Training Set Evaluation:
# Mean Absolute Error (MAE): 0.03168280973731928
# Mean Squared Error (MSE): 0.002199809291889039
# Root Mean Squared Error (RMSE): 0.046902124598881864
# Mean Absolute Percentage Error (MAPE): 1.7595506223151571
# R-squared (R2): 0.9978029998912066

# %% [markdown]
# # Testing Result

# %%
print("\nANN Testing Set Evaluation:")
calculate_metrics(y_test,test_pred_ann.flatten())
# Out:
# ANN Testing Set Evaluation:
# Mean Absolute Error (MAE): 0.026695835722287446
# Mean Squared Error (MSE): 0.00086853020162266
# Root Mean Squared Error (RMSE): 0.02947083645950111
# Mean Absolute Percentage Error (MAPE): 0.18628025208388838
# R-squared (R2): 0.9605997176480692

# %%
# Forecasting the training as well as testing sets.
def plot_actual_vs_predicted(index, y_test, tst_prd_dt, test_pred_cnn, title='Actual vs. Predicted Price', xlabel='Date', ylabel='Price'):

    # Creating a Data-Frame for plotting
    plot_df=pdns.DataFrame({
        'Actual': y_test,
        'Predicted_rf': tst_prd_dt,
        'Predicted_ann': test_pred_cnn.flatten()
    }, index=index)

    # Charting the current and anticipated pricing.
    mtpl.figure(figsize=(12,6))
    # Creating a line graph by plotting the value from plot_df.
    mtpl.plot(plot_df.index,plot_df['Actual'],label='Actual Price',color='blue')
    #The value from plot_df is plotted to create a line graph.
    mtpl.plot(plot_df.index,plot_df['Predicted_rf'],label='Predicted Price (Random Forest)',color='green')
    # getting the plotted with the datagrame with parameter
    mtpl.plot(plot_df.index,plot_df['Predicted_ann'],label='Predicted Price (ANN Model)',color='red')

    # setting the headertext in the plot
    mtpl.title(title,fontsize=16)
    # establishing the labels for the x and y axes
    mtpl.xlabel(xlabel,fontsize=14)
    # putting labels on the x and y axes
    mtpl.ylabel(ylabel,fontsize=14)

    # Include the grid and legend.
    mtpl.legend()
    # Adding grid lines for clarity
    mtpl.grid(True)

    # To improve readability, rotate the x-axis labels.
    mtpl.xticks(rotation=45)

    # Ensuring the plot layout is optimized
    mtpl.tight_layout()

    # Displaying the plot
    mtpl.show()

# %%
plot_actual_vs_predicted(
    index=STC_DTA_denoised.index[-len(y_test):], #date
    y_test=y_test, #actual values
    tst_prd_dt=pd_rf_stc, #predicted
    test_pred_cnn=test_pred_ann,
    title='Actual vs. Predicted Price (Random Forest  & ANN Model)',
    xlabel='Date',
    ylabel='Price'
)

# %%
def plot_model_metrics_comparison(y_test, tst_prd_dt, test_pred_cnn, model_names=['a', 'b']):

    # Create a dictionary to store the metrics for each model
    metrics_data = {
        model_names[0]: {
            'MAE': mean_absolute_error(y_test,tst_prd_dt),
            'MSE': mean_squared_error(y_test,tst_prd_dt),
            'RMSE': nmy.sqrt(mean_squared_error(y_test,tst_prd_dt)),
            'MAPE': nmy.mean(nmy.abs((y_test - tst_prd_dt) / y_test)) * 10,
            'R2': r2_score(y_test,tst_prd_dt)
        },
        model_names[1]: {
            'MAE': mean_absolute_error(y_test,test_pred_cnn.flatten()),
            'MSE': mean_squared_error(y_test,test_pred_cnn.flatten()),
            'RMSE': nmy.sqrt(mean_squared_error(y_test,test_pred_cnn.flatten())),
            'MAPE': nmy.mean(nmy.abs((y_test - test_pred_cnn.flatten()) / y_test)) * 10,
            'R2': r2_score(y_test,test_pred_cnn.flatten())
        }
    }

    # Create a list of metrics
    metrics=['MAE', 'MSE', 'RMSE', 'MAPE', 'R2']

    # Constructing the bar graph's figure and axes.
    fig,ax=mtpl.subplots(figsize=(10, 6))

   # Defining how wide the bars are.
    bar_width=0.35
    # Determine the bar placements on the x-axis.
    x=nmy.arange(len(metrics))

    # Plot the bars for each model
    rects1 = ax.bar(x - bar_width / 2, [metrics_data[model_names[0]][metric] for metric in metrics],
                    width=bar_width, label=model_names[0], color='green') #bars for RF
    rects2 = ax.bar(x + bar_width / 2, [metrics_data[model_names[1]][metric] for metric in metrics],
                    width=bar_width, label=model_names[1], color='red')

    # Configure tick labels on the x-axis.
    ax.set_xticks(x)
    ax.set_xticklabels(metrics)

   # Assign axis headings and a heading.
    ax.set_title(f'Comparison of {model_names[0]} and {model_names[1]} Model Performance')
    ax.set_ylabel('Metric Value')

    # Add a legend
    ax.legend()

    # Add grid lines for clarity
    ax.grid(True, linestyle='--', alpha=0.7)

    # Adding result value labels on top of the bars
    def autolabel(rects):
       # applying the looping the values
        for rect in rects:
           # getting the values of heiht
            height=rect.get_height()
            # showing the values of graph
            ax.annotate(f'{height:.2f}',
                        # Setting the position of the annotation text
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        # Adjust the annotation text's position.
                        xytext=(0, 3),
                        # Specify that the offset is in points relative to the original position
                        textcoords="offset points",
                        # Setting the color of the annotation text
                        ha='center', va='bottom', fontsize=8)

    autolabel(rects1)
    autolabel(rects2)

    # Ensure the layout is tight and show the plot
    mtpl.tight_layout()
    mtpl.show()

# %%
# Assuming `y_test`, `tst_prd_dt`, and `test_pred_cnn` are already defined:
plot_model_metrics_comparison(y_test, pd_rf_stc, test_pred_ann, model_names=['Random Forest', 'ANN Model'])

# %% [markdown]
# # Mobily Dataset

# %%
time_steps = 20

#Reforming the  to fit the LSTM
def reshape_data(data, time_steps=20):
    X, y = [], []
    #Resolved the indexing problem
    for i in range(len(data) - time_steps -1):
        # Click on Price_scaled, the first column.
        X.append(data[i:(i + time_steps), 0])
        # Select the first column (Price_scaled)
        y.append(data[i + time_steps, 0])
    return nmy.array(X), nmy.array(y)

# Converting the to a 2D array (adding a second dimension)
MOB_scaled_Denoise=MOB_DTA_denoised['Price'].values.reshape(-1, 1)

# Make use of reshape_data
X, y= reshape_data(MOB_scaled_Denoise, time_steps)

# %%
# Determining the training size by subtracting 14 from the length of X
train_size_MOB=len(X) - 14
# Splitting the feature data X into training and testing sets
X_train_mob,X_test_mob=X[:train_size_MOB],X[train_size_MOB:]
# Separating the feature dataset X into sets for testing and training
y_train_mob,y_test_mob=y[:train_size_MOB],y[train_size_MOB:]

# %%
print("X_train_mob shape:",X_train_mob.shape)
print("y_train_mob shape:",y_train_mob.shape)
print("X_test_mob shape:",X_test_mob.shape)
print("y_test_mob shape:",y_test_mob.shape)
# Out:
# X_train_mob shape: (1436, 20)
# y_train_mob shape: (1436,)
# X_test_mob shape: (14, 20)
# y_test_mob shape: (14,)

# %% [markdown]
# # Random Forest Regression

# %%
# Initialize the with tuned hyper-para-meters (increased complexity)
rf_model_mob=RandomForestRegressor(n_estimators=100,max_depth=20,min_samples_split=3,random_state=42)

# Educate the example to emulate
rf_model_mob.fit(X_train_mob,y_train_mob)

# Make forecasts using the test set.
pd_rf_mob=rf_model_mob.predict(X_test_mob)
# obtaining the variable values using the tested data
trn_rf_mob=rf_model_mob.predict(X_train_mob)

# %% [markdown]
# # Training Result

# %%
# Use the training set to assess the model.
print("Mobily Training Set Evaluation:")
calculate_metrics(y_train_mob, trn_rf_mob)
# Out:
# Mobily Training Set Evaluation:
# Mean Absolute Error (MAE): 0.011223269292883687
# Mean Squared Error (MSE): 0.00039146032092253144
# Root Mean Squared Error (RMSE): 0.01978535622430214
# Mean Absolute Percentage Error (MAPE): 1.6715307022098158
# R-squared (R2): 0.9996030374590142

# %% [markdown]
# # Testing Result

# %%
# Assess the model using the training data.
print("\nMobily Testing Set Evaluation:")
calculate_metrics(y_test_mob, pd_rf_mob)
# Out:
# Mobily Testing Set Evaluation:
# Mean Absolute Error (MAE): 0.044160541859762335
# Mean Squared Error (MSE): 0.0031766426133759463
# Root Mean Squared Error (RMSE): 0.05636171229989332
# Mean Absolute Percentage Error (MAPE): 1.257840157760475
# R-squared (R2): 0.9353416531494145

# %% [markdown]
# # Reshape the dataset

# %%
# Reshape the data for ANN
X_train_ann_mob=X_train_mob.reshape(X_train_mob.shape[0],X_train_mob.shape[1], 1)
X_test_ann_mob=X_test_mob.reshape(X_test_mob.shape[0],X_test_mob.shape[1], 1)

# %% [markdown]
# # ANN Model

# %%
mol_ann_mob=Sequential()
# Include the first dense layer with the ReLU activation function and 100 units (neurons) in the model.
mol_ann_mob.add(Dense(units=100,activation='relu',input_dim=X_train_ann_mob.shape[1]))
# Adding another dense layer with 50 units and ReLU activation.
mol_ann_mob.add(Dense(units=50,activation='relu'))
# Including a ReLU activation function and a third dense layer with 25 units (neurons).
mol_ann_mob.add(Dense(units=25,activation='relu'))
# Adding the output Dense layer with 1 unit. Since this is likely a regression
mol_ann_mob.add(Dense(units=1))

#Building the model using a new learning rate and optimizer
mol_ann_mob.compile(optimizer='adam',loss='mse')

# Use a larger batch size and much more epochs to train the model.
mol_ann_mob.fit(X_train_ann_mob,y_train_mob,epochs=130,batch_size=64,verbose=1,validation_data=(X_test_ann_mob,y_test_mob))
# Out:
# Epoch 1/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5032 - val_loss: 0.0405
# Epoch 2/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0323 - val_loss: 0.0305
# Epoch 3/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136 - val_loss: 0.0239
# Epoch 4/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - val_loss: 0.0220
# Epoch 5/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.0185
# Epoch 6/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0171
# Epoch 7/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - val_loss: 0.0163
# Epoch 8/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - val_loss: 0.0173
# Epoch 9/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0149
# Epoch 10/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0149
# Epoch 11/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - val_loss: 0.0167
# Epoch 12/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 0.0142
# Epoch 13/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0147
# Epoch 14/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - val_loss: 0.0131
# Epoch 15/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - val_loss: 0.0122
# Epoch 16/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - val_loss: 0.0122
# Epoch 17/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - val_loss: 0.0113
# Epoch 18/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - val_loss: 0.0104
# Epoch 19/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - val_loss: 0.0097
# Epoch 20/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - val_loss: 0.0097
# Epoch 21/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - val_loss: 0.0118
# Epoch 22/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0088
# Epoch 23/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - val_loss: 0.0099
# Epoch 24/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0088
# Epoch 25/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - val_loss: 0.0117
# Epoch 26/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - val_loss: 0.0084
# Epoch 27/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 0.0092
# Epoch 28/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0103
# Epoch 29/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - val_loss: 0.0101
# Epoch 30/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0107
# Epoch 31/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0086
# Epoch 32/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - val_loss: 0.0091
# Epoch 33/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0083
# Epoch 34/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0089
# Epoch 35/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0097
# Epoch 36/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 37/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 0.0088
# Epoch 38/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0106
# Epoch 39/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0090
# Epoch 40/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0086
# Epoch 41/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0087
# Epoch 42/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 43/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0105
# Epoch 44/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0097
# Epoch 45/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0086
# Epoch 46/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0075
# Epoch 47/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0079
# Epoch 48/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0078
# Epoch 49/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0072
# Epoch 50/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0084
# Epoch 51/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0079
# Epoch 52/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0094
# Epoch 53/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0075
# Epoch 54/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 55/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 56/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0086
# Epoch 57/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0067
# Epoch 58/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0102
# Epoch 59/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0088
# Epoch 60/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0080
# Epoch 61/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0080
# Epoch 62/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0074
# Epoch 63/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0083
# Epoch 64/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0074
# Epoch 65/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 66/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - val_loss: 0.0083
# Epoch 67/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0092
# Epoch 68/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0132
# Epoch 69/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0114
# Epoch 70/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 71/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0104
# Epoch 72/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0078
# Epoch 73/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0086
# Epoch 74/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0096
# Epoch 75/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0092
# Epoch 76/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0092
# Epoch 77/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0094
# Epoch 78/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0098
# Epoch 79/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0086
# Epoch 80/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - val_loss: 0.0082
# Epoch 81/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 82/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0090
# Epoch 83/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 84/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 85/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0068
# Epoch 86/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - val_loss: 0.0066
# Epoch 87/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0081
# Epoch 88/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 0.0080
# Epoch 89/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 90/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0073
# Epoch 91/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0086
# Epoch 92/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 93/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0083
# Epoch 94/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0083
# Epoch 95/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0083
# Epoch 96/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0078
# Epoch 97/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0073
# Epoch 98/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0063
# Epoch 99/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - val_loss: 0.0071
# Epoch 100/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0070
# Epoch 101/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0087
# Epoch 102/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0115
# Epoch 103/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0086
# Epoch 104/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0071
# Epoch 105/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 106/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0085
# Epoch 107/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0113
# Epoch 108/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0064
# Epoch 109/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0071
# Epoch 110/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0077
# Epoch 111/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - val_loss: 0.0060
# Epoch 112/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0080
# Epoch 113/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - val_loss: 0.0058
# Epoch 114/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - val_loss: 0.0082
# Epoch 115/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 116/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0076
# Epoch 117/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - val_loss: 0.0070
# Epoch 118/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0091
# Epoch 119/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 120/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - val_loss: 0.0062
# Epoch 121/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 122/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 123/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - val_loss: 0.0064
# Epoch 124/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0060
# Epoch 125/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0075
# Epoch 126/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0068
# Epoch 127/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0059
# Epoch 128/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0085
# Epoch 129/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - val_loss: 0.0076
# Epoch 130/130
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0071

# %%
mol_ann_mob.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 100)                 │           2,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,355 (99.05 KB)
#  Trainable params: 8,451 (33.01 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 16,904 (66.04 KB)

# %%
# Predicting using the testing along with training sets.
train_pred_ann_mob=mol_ann_mob.predict(X_train_ann_mob)
# getting the values of testing information
test_pred_ann_mob=mol_ann_mob.predict(X_test_ann_mob)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %% [markdown]
# # Training Result

# %%
# # Training Result
calculate_metrics(y_train_mob,train_pred_ann_mob.flatten())
# Out:
# Mean Absolute Error (MAE): 0.027900652850424496
# Mean Squared Error (MSE): 0.001991550637702707
# Root Mean Squared Error (RMSE): 0.044626792823400464
# Mean Absolute Percentage Error (MAPE): 1.759305755629117
# R-squared (R2): 0.9979804568703636

# %% [markdown]
# # Testing Result

# %%
#Testing Result
calculate_metrics(y_test_mob,test_pred_ann_mob.flatten())
# Out:
# Mean Absolute Error (MAE): 0.06878384505461595
# Mean Squared Error (MSE): 0.007145593767252922
# Root Mean Squared Error (RMSE): 0.08453161401069378
# Mean Absolute Percentage Error (MAPE): 2.577424550136251
# R-squared (R2): 0.8545564180525137

# %%
plot_actual_vs_predicted(
    index=MOB_DTA_denoised.index[-len(y_test_mob):],
    y_test=y_test_mob,
    tst_prd_dt=pd_rf_mob,
    test_pred_cnn=test_pred_ann_mob,
    title='Actual vs. Predicted Price (Random Forest & ANN Model) Mobily Dataset',
    xlabel='Date',
    ylabel='Price'
)

# %%
plot_model_metrics_comparison(y_test_mob, pd_rf_mob, test_pred_ann_mob, model_names=['Random Forest', 'ANN Model'])

# %% [markdown]
# # Zain Dataset

# %%
time_steps = 20

# Modifying the information for the LSTM approach
def reshape_data(data,time_steps=20):
    X, y = [],[]
    #Fixed the indexing issue
    for i in range(len(data) - time_steps -1):
        # Select the first column (Price_scaled)
        X.append(data[i:(i + time_steps), 0])
        # Choose the Price_scaled column.
        y.append(data[i + time_steps, 0])
    # returning the array with the data
    return nmy.array(X), nmy.array(y)

# Converting to a 2D array (adding a second dimension)
ZAIN_scld_Denoise=ZAIN_DTA_denoised['Price'].values.reshape(-1, 1)

# Make use of reshape_data
X, y =reshape_data(ZAIN_scld_Denoise, time_steps)

# %%
train_size_ZAIN=len(X) - 14
X_train_zain,X_test_zain=X[:train_size_ZAIN],X[train_size_ZAIN:]
y_train_zain,y_test_zain = y[:train_size_ZAIN],y[train_size_ZAIN:]

# %%
print("X_train_zain shape:",X_train_zain.shape)
print("y_train_zain shape:",y_train_zain.shape)
print("X_test_zain shape:",X_test_zain.shape)
print("y_test_zain shape:",y_test_zain.shape)
# Out:
# X_train_zain shape: (1434, 20)
# y_train_zain shape: (1434,)
# X_test_zain shape: (14, 20)
# y_test_zain shape: (14,)

# %% [markdown]
# # Random Forest Regression

# %%
# Initializing the with tuned hyper-para-meters
rf_model_zain=RandomForestRegressor(n_estimators=200,max_depth=20,min_samples_split=2,random_state=42)

# Educating the example to emulate
rf_model_zain.fit(X_train_zain,y_train_zain)

#Create forecasts for the test set.
pd_rf_zain=rf_model_zain.predict(X_test_zain)
#Generate test set forecasts.
trn_rf_zain=rf_model_zain.predict(X_train_zain)

# %% [markdown]
# # Training Result

# %%
# Use the training set to assess the model.
print("Zain Training Set Evaluation:")
calculate_metrics(y_train_zain, trn_rf_zain)
# Out:
# Zain Training Set Evaluation:
# Mean Absolute Error (MAE): 0.012900958426995374
# Mean Squared Error (MSE): 0.0004964646733505033
# Root Mean Squared Error (RMSE): 0.022281487233811466
# Mean Absolute Percentage Error (MAPE): 0.8417607930467523
# R-squared (R2): 0.9995082219855984

# %% [markdown]
# # Testing Result

# %%
# Examine the model using the test data.
calculate_metrics(y_test_zain, pd_rf_zain)
# Out:
# Mean Absolute Error (MAE): 0.0273327380282312
# Mean Squared Error (MSE): 0.001175999950530268
# Root Mean Squared Error (RMSE): 0.034292855677681144
# Mean Absolute Percentage Error (MAPE): 0.2693255851611723
# R-squared (R2): 0.7787298650324271

# %% [markdown]
# # Reshape the dataset

# %%
# Reshape the data for ANN
X_train_ann_zain=X_train_zain.reshape(X_train_zain.shape[0],X_train_zain.shape[1], 1)
X_test_ann_zain=X_test_zain.reshape(X_test_zain.shape[0],X_test_zain.shape[1], 1)

# %% [markdown]
# # ANN Model

# %%
mod_ann_zain=Sequential()
#The input dimension is set to the number of features in the training data.
mod_ann_zain.add(Dense(units=150,activation='relu',input_dim=X_train_ann_zain.shape[1]))
# Adding a second Dense layers activation function.
mod_ann_zain.add(Dense(units=75,activation='relu'))
# Include a ReLU activation function and 25 units (neurons).
mod_ann_zain.add(Dense(units=30,activation='relu'))
# Include one unit of the output Dense layer. Given that this task is probably a regression one,
mod_ann_zain.add(Dense(units=1))

#building the algorithms with a different optimizer and learning rate
mod_ann_zain.compile(optimizer='adam',loss='mse')

# Train the model with more epochs and a larger batch size
mod_ann_zain.fit(X_train_ann_zain,y_train_zain,epochs=100,batch_size=16,verbose=1,validation_data=(X_test_ann_zain,y_test_zain))
# Out:
# Epoch 1/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1097 - val_loss: 0.0102
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0117 - val_loss: 0.0069
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - val_loss: 0.0024
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - val_loss: 0.0028
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - val_loss: 0.0069
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0080
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 30/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 31/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 32/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 33/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 34/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 35/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 36/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 37/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 38/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 39/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 40/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 41/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 42/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 43/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 44/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 45/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 46/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 47/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 48/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 49/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 50/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 51/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 52/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 53/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 54/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 55/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 56/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 57/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 58/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 59/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 60/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 61/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 62/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 63/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 64/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 65/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 66/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 67/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 68/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 69/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 70/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 71/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 72/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 73/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 74/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 75/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 76/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 77/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 78/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 79/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 80/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 81/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 82/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 83/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 84/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 85/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 86/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 87/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 88/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 89/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 90/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 91/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 92/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 93/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 94/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 95/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 96/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 97/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 98/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 99/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 100/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0014

# %%
# Prediction using the testing and practice sets.
train_pred_ann_zain=mod_ann_zain.predict(X_train_ann_zain)
test_pred_ann_zain=mod_ann_zain.predict(X_test_ann_zain)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# # Training Result

# %%
# # Training Result
calculate_metrics(y_train_zain, train_pred_ann_zain.flatten())
# Out:
# Mean Absolute Error (MAE): 0.026048004269312204
# Mean Squared Error (MSE): 0.0016577086100333096
# Root Mean Squared Error (RMSE): 0.0407149678869247
# Mean Absolute Percentage Error (MAPE): 0.8710905347701214
# R-squared (R2): 0.9983579402675383

# %% [markdown]
# # Testing Result

# %%
# # Testing Result
calculate_metrics(y_test_zain, test_pred_ann_zain.flatten())
# Out:
# Mean Absolute Error (MAE): 0.032437983482487644
# Mean Squared Error (MSE): 0.0014163391360364384
# Root Mean Squared Error (RMSE): 0.037634281393915815
# Mean Absolute Percentage Error (MAPE): 0.314670989691209
# R-squared (R2): 0.7335088733215283

# %%
plot_actual_vs_predicted(
    index=ZAIN_DTA_denoised.index[-len(y_test_zain):],
    y_test=y_test_zain,
    tst_prd_dt=pd_rf_zain,
    test_pred_cnn=test_pred_ann_zain,
    title='Actual vs. Predicted Price (Random Forest & ANN Model) Zain Dataset',
    xlabel='Date',
    ylabel='Price'
)

# %%
plot_model_metrics_comparison(y_test_zain, pd_rf_zain, test_pred_ann_zain, model_names=['Random Forest', 'ANN Model'])
